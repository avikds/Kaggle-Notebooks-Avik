# %% [markdown]
# <a href="https://www.kaggle.com/code/avikdas567/exercise-binary-classification?scriptVersionId=298046801" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *
# Out:
# /tmp/ipykernel_18/3338970720.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# 2026-02-16 14:49:26.605426: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-16 14:49:26.605543: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-16 14:49:26.734412: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Correct

# %%
q_1.hint()
q_1.solution()
# Out:
# Hint: Your answer should look something like:
# ```python
# model = keras.Sequential([
#     # Batch Normalization
#
#     # Dense
#     # Batch Normalization
#     # Dropout
#
#     # Dense
#     # Batch Normalization
#     # Dropout
#
#     # Dense
# ])
# ```
# Solution:
# ```python
#
# from tensorflow import keras
# from tensorflow.keras import layers
#
# model = keras.Sequential([
#     layers.BatchNormalization(input_shape=input_shape),
#     layers.Dense(256, activation='relu'),
#     layers.BatchNormalization(),
#     layers.Dropout(0.3),
#     layers.Dense(256, activation='relu'),
#     layers.BatchNormalization(),
#     layers.Dropout(0.3),
#     layers.Dense(1, activation='sigmoid'),
# ])
# q_1.assert_check_passed()
#
# ```

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
q_2.hint()
q_2.solution()
# Out:
# Hint: Your code should look something like:
# ```python
# model.compile(
# optimizer=____,
# loss=____,
# metrics=____,
# )
# ```
# Solution:
# ```python
#
# model.compile(
#     optimizer='adam',
#     loss='binary_crossentropy',
#     metrics=['binary_accuracy'],
# )
#
# ```

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 4s 15ms/step - loss: 0.4796 - binary_accuracy: 0.7728 - val_loss: 0.4296 - val_binary_accuracy: 0.8041
# Epoch 2/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.4242 - binary_accuracy: 0.8008 - val_loss: 0.4020 - val_binary_accuracy: 0.8136
# Epoch 3/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.4112 - binary_accuracy: 0.8080 - val_loss: 0.3963 - val_binary_accuracy: 0.8156
# Epoch 4/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.4028 - binary_accuracy: 0.8111 - val_loss: 0.3895 - val_binary_accuracy: 0.8193
# Epoch 5/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3983 - binary_accuracy: 0.8141 - val_loss: 0.3846 - val_binary_accuracy: 0.8243
# Epoch 6/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3932 - binary_accuracy: 0.8162 - val_loss: 0.3856 - val_binary_accuracy: 0.8236
# Epoch 7/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3892 - binary_accuracy: 0.8188 - val_loss: 0.3790 - val_binary_accuracy: 0.8282
# Epoch 8/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3863 - binary_accuracy: 0.8214 - val_loss: 0.3768 - val_binary_accuracy: 0.8274
# Epoch 9/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3820 - binary_accuracy: 0.8228 - val_loss: 0.3747 - val_binary_accuracy: 0.8278
# Epoch 10/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3796 - binary_accuracy: 0.8247 - val_loss: 0.3734 - val_binary_accuracy: 0.8279
# Epoch 11/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3780 - binary_accuracy: 0.8249 - val_loss: 0.3706 - val_binary_accuracy: 0.8302
# Epoch 12/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3749 - binary_accuracy: 0.8258 - val_loss: 0.3692 - val_binary_accuracy: 0.8300
# Epoch 13/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3714 - binary_accuracy: 0.8297 - val_loss: 0.3681 - val_binary_accuracy: 0.8317
# Epoch 14/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3692 - binary_accuracy: 0.8296 - val_loss: 0.3640 - val_binary_accuracy: 0.8331
# Epoch 15/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3675 - binary_accuracy: 0.8303 - val_loss: 0.3628 - val_binary_accuracy: 0.8324
# Epoch 16/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3661 - binary_accuracy: 0.8312 - val_loss: 0.3629 - val_binary_accuracy: 0.8326
# Epoch 17/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3645 - binary_accuracy: 0.8319 - val_loss: 0.3610 - val_binary_accuracy: 0.8333
# Epoch 18/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3636 - binary_accuracy: 0.8327 - val_loss: 0.3602 - val_binary_accuracy: 0.8344
# Epoch 19/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3622 - binary_accuracy: 0.8324 - val_loss: 0.3587 - val_binary_accuracy: 0.8355
# Epoch 20/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3598 - binary_accuracy: 0.8338 - val_loss: 0.3603 - val_binary_accuracy: 0.8347
# Epoch 21/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3589 - binary_accuracy: 0.8339 - val_loss: 0.3602 - val_binary_accuracy: 0.8357
# Epoch 22/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3565 - binary_accuracy: 0.8363 - val_loss: 0.3582 - val_binary_accuracy: 0.8340
# Epoch 23/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3562 - binary_accuracy: 0.8359 - val_loss: 0.3557 - val_binary_accuracy: 0.8355
# Epoch 24/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3543 - binary_accuracy: 0.8368 - val_loss: 0.3569 - val_binary_accuracy: 0.8367
# Epoch 25/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3530 - binary_accuracy: 0.8373 - val_loss: 0.3572 - val_binary_accuracy: 0.8370
# Epoch 26/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3514 - binary_accuracy: 0.8376 - val_loss: 0.3545 - val_binary_accuracy: 0.8358
# Epoch 27/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3507 - binary_accuracy: 0.8386 - val_loss: 0.3544 - val_binary_accuracy: 0.8370
# Epoch 28/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3505 - binary_accuracy: 0.8372 - val_loss: 0.3555 - val_binary_accuracy: 0.8356
# Epoch 29/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3492 - binary_accuracy: 0.8388 - val_loss: 0.3526 - val_binary_accuracy: 0.8381
# Epoch 30/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3480 - binary_accuracy: 0.8398 - val_loss: 0.3546 - val_binary_accuracy: 0.8373
# Epoch 31/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3465 - binary_accuracy: 0.8407 - val_loss: 0.3539 - val_binary_accuracy: 0.8373
# Epoch 32/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3470 - binary_accuracy: 0.8387 - val_loss: 0.3518 - val_binary_accuracy: 0.8377
# Epoch 33/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3449 - binary_accuracy: 0.8415 - val_loss: 0.3511 - val_binary_accuracy: 0.8391
# Epoch 34/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3433 - binary_accuracy: 0.8421 - val_loss: 0.3535 - val_binary_accuracy: 0.8383
# Epoch 35/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3428 - binary_accuracy: 0.8421 - val_loss: 0.3513 - val_binary_accuracy: 0.8381
# Epoch 36/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3420 - binary_accuracy: 0.8422 - val_loss: 0.3517 - val_binary_accuracy: 0.8376
# Epoch 37/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3416 - binary_accuracy: 0.8420 - val_loss: 0.3499 - val_binary_accuracy: 0.8395
# Epoch 38/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3407 - binary_accuracy: 0.8432 - val_loss: 0.3492 - val_binary_accuracy: 0.8395
# Epoch 39/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3390 - binary_accuracy: 0.8441 - val_loss: 0.3514 - val_binary_accuracy: 0.8387
# Epoch 40/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3390 - binary_accuracy: 0.8440 - val_loss: 0.3501 - val_binary_accuracy: 0.8400
# Epoch 41/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3395 - binary_accuracy: 0.8438 - val_loss: 0.3502 - val_binary_accuracy: 0.8383
# Epoch 42/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3369 - binary_accuracy: 0.8451 - val_loss: 0.3488 - val_binary_accuracy: 0.8399
# Epoch 43/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3363 - binary_accuracy: 0.8451 - val_loss: 0.3497 - val_binary_accuracy: 0.8390
# Epoch 44/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3376 - binary_accuracy: 0.8433 - val_loss: 0.3496 - val_binary_accuracy: 0.8408
# Epoch 45/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3355 - binary_accuracy: 0.8451 - val_loss: 0.3512 - val_binary_accuracy: 0.8393
# Epoch 46/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3332 - binary_accuracy: 0.8463 - val_loss: 0.3482 - val_binary_accuracy: 0.8403
# Epoch 47/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3349 - binary_accuracy: 0.8455 - val_loss: 0.3486 - val_binary_accuracy: 0.8411
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
