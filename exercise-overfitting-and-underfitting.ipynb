# %% [markdown]
# <a href="https://www.kaggle.com/code/avikdas567/exercise-overfitting-and-underfitting?scriptVersionId=298043618" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/overfitting-and-underfitting).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you’ll learn how to improve training outcomes by including an early stopping callback to prevent overfitting.
#
# When you're ready, run this next cell to set everything up!

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex4 import *
# Out:
# /tmp/ipykernel_27/1500229236.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# First load the *Spotify* dataset. Your task will be to predict the popularity of a song based on various audio features, like `'tempo'`, `'danceability'`, and `'mode'`.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.model_selection import GroupShuffleSplit

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks

spotify = pd.read_csv('../input/dl-course-data/spotify.csv')

X = spotify.copy().dropna()
y = X.pop('track_popularity')
artists = X['track_artist']

features_num = ['danceability', 'energy', 'key', 'loudness', 'mode',
                'speechiness', 'acousticness', 'instrumentalness',
                'liveness', 'valence', 'tempo', 'duration_ms']
features_cat = ['playlist_genre']

preprocessor = make_column_transformer(
    (StandardScaler(), features_num),
    (OneHotEncoder(), features_cat),
)

# We'll do a "grouped" split to keep all of an artist's songs in one
# split or the other. This is to help prevent signal leakage.
def group_split(X, y, group, train_size=0.75):
    splitter = GroupShuffleSplit(train_size=train_size)
    train, test = next(splitter.split(X, y, groups=group))
    return (X.iloc[train], X.iloc[test], y.iloc[train], y.iloc[test])

X_train, X_valid, y_train, y_valid = group_split(X, y, artists)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)
y_train = y_train / 100 # popularity is on a scale 0-100, so this rescales to 0-1.
y_valid = y_valid / 100

input_shape = [X_train.shape[1]]
print("Input shape: {}".format(input_shape))
# Out:
# 2026-02-16 14:29:53.324972: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-16 14:29:53.325073: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-16 14:29:53.481049: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Input shape: [18]

# %% [markdown]
# Let's start with the simplest network, a linear model. This model has low capacity.
#
# Run this next cell without any changes to train a linear model on the *Spotify* dataset.

# %%
model = keras.Sequential([
    layers.Dense(1, input_shape=input_shape),
])
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
    verbose=0, # suppress output since we'll plot the curves
)
history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771252204.871365      67 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Minimum Validation Loss: 0.1936

# %% [markdown]
# It's not uncommon for the curves to follow a "hockey stick" pattern like you see here. This makes the final part of training hard to see, so let's start at epoch 10 instead:

# %%
# Start the plot at epoch 10
history_df.loc[10:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# Minimum Validation Loss: 0.1936

# %% [markdown]
# # 1) Evaluate Baseline
#
# What do you think? Would you say this model is underfitting, overfitting, just right?

# %%
# View the solution (Run this cell to receive credit!)
q_1.check()
# Out:
# Correct:
#
# The gap between these curves is quite small and the validation loss never increases, so it's more likely that the network is underfitting than overfitting. It would be worth experimenting with more capacity to see if that's the case.

# %% [markdown]
# Now let's add some capacity to our network. We'll add three hidden layers with 128 units each. Run the next cell to train the network and see the learning curves.

# %%
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
)
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# Epoch 1/50
# 49/49 [==============================] - 1s 6ms/step - loss: 0.2275 - val_loss: 0.2023
# Epoch 2/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.2019 - val_loss: 0.1974
# Epoch 3/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1971 - val_loss: 0.1966
# Epoch 4/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1941 - val_loss: 0.1949
# Epoch 5/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1922 - val_loss: 0.1942
# Epoch 6/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1906 - val_loss: 0.1967
# Epoch 7/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1892 - val_loss: 0.1933
# Epoch 8/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1873 - val_loss: 0.1939
# Epoch 9/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1868 - val_loss: 0.1932
# Epoch 10/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1860 - val_loss: 0.1956
# Epoch 11/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1854 - val_loss: 0.1941
# Epoch 12/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1843 - val_loss: 0.1938
# Epoch 13/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1836 - val_loss: 0.1949
# Epoch 14/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1822 - val_loss: 0.1938
# Epoch 15/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1824 - val_loss: 0.1939
# Epoch 16/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1812 - val_loss: 0.1936
# Epoch 17/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1803 - val_loss: 0.1940
# Epoch 18/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1802 - val_loss: 0.1940
# Epoch 19/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1797 - val_loss: 0.1953
# Epoch 20/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1788 - val_loss: 0.1953
# Epoch 21/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1783 - val_loss: 0.1993
# Epoch 22/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1785 - val_loss: 0.1954
# Epoch 23/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1768 - val_loss: 0.1957
# Epoch 24/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1768 - val_loss: 0.1957
# Epoch 25/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1759 - val_loss: 0.1963
# Epoch 26/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1758 - val_loss: 0.1953
# Epoch 27/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1746 - val_loss: 0.1970
# Epoch 28/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1750 - val_loss: 0.1973
# Epoch 29/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1741 - val_loss: 0.1969
# Epoch 30/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1741 - val_loss: 0.1960
# Epoch 31/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1729 - val_loss: 0.1960
# Epoch 32/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1725 - val_loss: 0.1974
# Epoch 33/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1718 - val_loss: 0.1968
# Epoch 34/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1717 - val_loss: 0.1982
# Epoch 35/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1712 - val_loss: 0.1992
# Epoch 36/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1708 - val_loss: 0.1975
# Epoch 37/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1719 - val_loss: 0.1984
# Epoch 38/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1706 - val_loss: 0.1975
# Epoch 39/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1691 - val_loss: 0.1975
# Epoch 40/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1686 - val_loss: 0.1983
# Epoch 41/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1687 - val_loss: 0.1983
# Epoch 42/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1685 - val_loss: 0.1980
# Epoch 43/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1683 - val_loss: 0.1980
# Epoch 44/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1673 - val_loss: 0.1985
# Epoch 45/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1668 - val_loss: 0.1986
# Epoch 46/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1674 - val_loss: 0.1996
# Epoch 47/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1669 - val_loss: 0.2004
# Epoch 48/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1659 - val_loss: 0.1998
# Epoch 49/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1656 - val_loss: 0.1997
# Epoch 50/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1655 - val_loss: 0.1997
# Minimum Validation Loss: 0.1932

# %% [markdown]
# # 2) Add Capacity
#
# What is your evaluation of these curves? Underfitting, overfitting, just right?

# %%
# View the solution (Run this cell to receive credit!)
q_2.check()
# Out:
# Correct:
#
# Now the validation loss begins to rise very early, while the training loss continues to decrease. This indicates that the network has begun to overfit. At this point, we would need to try something to prevent it, either by reducing the number of units or through a method like early stopping. (We'll see another in the next lesson!)

# %% [markdown]
# # 3) Define Early Stopping Callback
#
# Now define an early stopping callback that waits 5 epochs (`patience'`) for a change in validation loss of at least `0.001` (`min_delta`) and keeps the weights with the best loss (`restore_best_weights`).

# %%
from tensorflow.keras import callbacks

early_stopping = callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)

# Check your answer
q_3.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
q_3.hint()
q_3.solution()
# Out:
# Hint:
# Your solution should look something like:
#
# ```python
# early_stopping = callbacks.EarlyStopping(
#     patience=____,
#     min_delta=____,
#     restore_best_weights=____,
# )
# ```
# Solution:
# ```python
#
# early_stopping = callbacks.EarlyStopping(
#     patience=5,
#     min_delta=0.001,
#     restore_best_weights=True,
# )
# ```

# %% [markdown]
# Now run this cell to train the model and get the learning curves. Notice the `callbacks` argument in `model.fit`.

# %%
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=input_shape),
    layers.Dense(64, activation='relu'),    
    layers.Dense(1)
])
model.compile(
    optimizer='adam',
    loss='mae',
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=50,
    callbacks=[early_stopping]
)
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
print("Minimum Validation Loss: {:0.4f}".format(history_df['val_loss'].min()));
# Out:
# Epoch 1/50
# 49/49 [==============================] - 1s 6ms/step - loss: 0.2428 - val_loss: 0.2036
# Epoch 2/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.2031 - val_loss: 0.1981
# Epoch 3/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1976 - val_loss: 0.1966
# Epoch 4/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1947 - val_loss: 0.1951
# Epoch 5/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1919 - val_loss: 0.1949
# Epoch 6/50
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1908 - val_loss: 0.1947
# Epoch 7/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1889 - val_loss: 0.1957
# Epoch 8/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1881 - val_loss: 0.1961
# Epoch 9/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1875 - val_loss: 0.1940
# Epoch 10/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1859 - val_loss: 0.1944
# Epoch 11/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1850 - val_loss: 0.1938
# Epoch 12/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1841 - val_loss: 0.1944
# Epoch 13/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1839 - val_loss: 0.1951
# Epoch 14/50
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1832 - val_loss: 0.1941
# Minimum Validation Loss: 0.1938

# %% [markdown]
# # 4) Train and Interpret
#
# Was this an improvement compared to training without early stopping?

# %%
# View the solution (Run this cell to receive credit!)
q_4.check()
# Out:
# Correct:
#
# The early stopping callback did stop the training once the network began overfitting. Moreover, by including `restore_best_weights` we still get to keep the model where validation loss was lowest.

# %% [markdown]
# If you like, try experimenting with `patience` and `min_delta` to see what difference it might make.
#
# # Keep Going #
#
# Move on to [**learn about a couple of special layers**](https://www.kaggle.com/ryanholbrook/dropout-and-batch-normalization): batch normalization and dropout.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
